# %%
import requests
import pandas as pd

# %%
url = "https://moviesdatabase.p.rapidapi.com/titles"

headers = {
    "X-RapidAPI-Key": "88702204bbmsh867095aced682fap1926a2jsn366e01bceee6",
    "X-RapidAPI-Host": "moviesdatabase.p.rapidapi.com"
}

# %%
response = requests.get(url, headers=headers, params={"limit": "20"})

if response.status_code == 200:
    data = response.json()
    
    
    df = pd.json_normalize(data['results'])
    
  
    df_clean = df.rename(columns={
        'titleText.text': 'Title',
        'releaseYear.year': 'Year',
        'titleType.text': 'Category'
    })
    
 
    df_final = df_clean[['id', 'Title', 'Year', 'Category']]
    
  
  
    display(df_final.head(20)) 
else:
    print(f"Error: {response.status_code}")
# Out:
#            id                                     Title  Year Category
# 0   tt0000081                    Les haleurs de bateaux  1896    Short
# 1   tt0000045                        Les blanchisseuses  1896    Short
# 2   tt0000066                  Dessinateur: Von Bismark  1896    Short
# 3   tt0000049           Boxing Match; or, Glove Contest  1896    Short
# 4   tt0000103                   Plus fort que le maître  1896    Short
# 5   tt0000133                      La voiture du potier  1896    Short
# 6   tt0000125             The Terrible Railway Accident  1896    Short
# 7   tt0000184              Cripple Creek Bar-Room Scene  1899    Short
# 8   tt0000109                     Rip Meeting the Dwarf  1896    Short
# 9   tt0000086  Jetée et plage de Trouville (1er partie)  1896    Short
# 10  tt0000105                     Les quais à Marseille  1896    Short
# 11  tt0000123                Séance de prestidigitation  1896    Short
# ...
